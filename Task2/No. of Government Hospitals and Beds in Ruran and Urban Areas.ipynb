# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_excel(r'C:\Users\asus\Downloads\Number of Government Hospitals and Beds in Rural and Urban Areas  1.xlsx')
df.head()
# Out:
#            States/UTs Rural hospitals Unnamed: 2 Urban hospitals Unnamed: 4  \
# 0                 NaN             No.       Beds             No.       Beds
# 1      Andhra Pradesh             193       6480              65      16658
# 2  Arunachal Pradesh*             208       2136              10        268
# 3               Assam            1176      10944              50       6198
# 4               Bihar             930       6083             103       5936
#
#         As on        state
# 0         NaN          NaN
# 1  01.01.2017   84580777.0
# 2  31.12.2017    1383727.0
# 3  31.12.2017   31205576.0
# 4  31.12.2016  104099452.0

# %%
df.rename (columns = {'Unnamed: 2': 'Beds in Rural', 'Unnamed: 4':'Beds in Urban', 'As on' : 'As on date' , 'States/UTs':'State'}, inplace = True)
# drop first row
df = df.drop(0)
df = df.drop(37)
df[['Rural hospitals','Beds in Rural','Urban hospitals','Beds in Urban']]=df[['Rural hospitals','Beds in Rural','Urban hospitals','Beds in Urban']].astype(int) 
df['State']= df['State'].str.replace('*','')
df['Total beds'] = df['Beds in Rural'] + df['Beds in Urban']
df['Total Hospital'] = df['Rural hospitals'] + df['Urban hospitals']
df.head()
# Out:
#                State  Rural hospitals  Beds in Rural  Urban hospitals  \
# 1     Andhra Pradesh              193           6480               65
# 2  Arunachal Pradesh              208           2136               10
# 3              Assam             1176          10944               50
# 4              Bihar              930           6083              103
# 5       Chhattisgarh              169           5070               45
#
#    Beds in Urban  As on date        state  Total beds  Total Hospital
# 1          16658  01.01.2017   84580777.0       23138             258
# 2            268  31.12.2017    1383727.0        2404             218
# 3           6198  31.12.2017   31205576.0       17142            1226
# 4           5936  31.12.2016  104099452.0       12019            1033
# 5           4342  01.01.2016   25545198.0        9412             214

# %%
df.head()
# Out:
#                State  Rural hospitals  Beds in Rural  Urban hospitals  \
# 1     Andhra Pradesh              193           6480               65
# 2  Arunachal Pradesh              208           2136               10
# 3              Assam             1176          10944               50
# 4              Bihar              930           6083              103
# 5       Chhattisgarh              169           5070               45
#
#    Beds in Urban  As on date        state  Total beds  Total Hospital
# 1          16658  01.01.2017   84580777.0       23138             258
# 2            268  31.12.2017    1383727.0        2404             218
# 3           6198  31.12.2017   31205576.0       17142            1226
# 4           5936  31.12.2016  104099452.0       12019            1033
# 5           4342  01.01.2016   25545198.0        9412             214

# %%
df.describe()
# Out:
#        Rural hospitals  Beds in Rural  Urban hospitals  Beds in Urban  \
# count        36.000000      36.000000        36.000000      36.000000
# mean        550.277778    7766.333333       104.777778   11977.027778
# std         862.228727    9955.553646       129.946387   15086.566553
# min           0.000000       0.000000         0.000000       0.000000
# 25%          23.750000     623.500000        13.250000    1369.750000
# 50%         240.500000    5735.000000        57.500000    5085.000000
# 75%         695.250000   10251.000000       128.750000   17198.250000
# max        4442.000000   40179.000000       525.000000   58882.000000
#
#               state    Total beds  Total Hospital
# count  3.600000e+01     36.000000       36.000000
# mean   3.359945e+07  19743.361111      655.055556
# std    4.227817e+07  23492.316477      927.461542
# min    6.447300e+04    240.000000        4.000000
# 25%    1.439840e+06   2302.250000       40.500000
# 50%    2.106970e+07  11445.500000      354.500000
# 75%    6.060359e+07  25497.000000      816.500000
# max    1.998123e+08  78566.000000     4635.000000

# %%
state_data = df[['State','Total Hospital','Total beds']]
state_data.drop(index = [30,31,32,33,36,35],inplace = True)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
plt.figure(figsize=(10,10))
plt.barh(df['State'],df['Rural hospitals'], label = 'Rural Hospitals')
plt.barh(df['State'],df['Urban hospitals'], label = 'Urban Hospitals')
plt.ylabel('States')
plt.xlabel('No. of hospital')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.barh(df['State'],df['Beds in Rural'], label = 'Beds in Rural')
plt.barh(df['State'],df['Beds in Urban'], label = 'Beds in Urban')
plt.ylabel('States')
plt.xlabel('No. of beds')
plt.legend()
plt.show()
